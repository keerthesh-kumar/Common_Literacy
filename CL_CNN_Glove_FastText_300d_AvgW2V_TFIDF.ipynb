# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# !ls "/content/drive/MyDrive/DeepLearning/Common Literacy"
# Out:
# CL_Bert_Base_Uncased.ipynb
# CL_CNN_BiLSTM_Glove100d_TFIDF.ipynb
# CL_CNN_Glove100d_TFIDF.ipynb
# CL_CNN_Model.ipynb
# CL_Glove100d_AVGW2V_POS.ipynb
# CL_Glove100d_AVGW2V_TFIDFAVGW2V_POS.ipynb
# CL_Glove100d_BOW_TFIDF_AvgW2V.ipynb
# CL_Glove100d_BOW_TFIDF_AvgW2V_SVD.ipynb
# CL_Glove100d_FastText_AVGW2V_POS.ipynb
# CL_Glove300d_BOW_TFIDF_AVGW2V.ipynb
# Dataset
# FastText
# GloveVector

# %%
train ='/content/drive/MyDrive/DeepLearning/Common Literacy/Dataset/train.csv'
test = '/content/drive/MyDrive/DeepLearning/Common Literacy/Dataset/test.csv'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
from tqdm import tqdm

import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.layers import LayerNormalization, BatchNormalization
from keras.layers import Embedding, LSTM, Bidirectional
from keras.layers import Conv1D, Flatten, MaxPool1D, GlobalMaxPooling1D, GlobalAveragePooling1D, AveragePooling1D
from keras.preprocessing.text import one_hot
from keras.preprocessing.sequence import pad_sequences
from keras.preprocessing.text import Tokenizer

from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.model_selection import cross_val_score, cross_val_predict
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %matplotlib inline

# %%
df_train = pd.read_csv(train)
df_test = pd.read_csv(test)

# %% [markdown]
# ### NLTK Stopwords Removal

# %%
# importing stopwords from nltk library
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.stem import PorterStemmer
nltk.download('stopwords')
nltk.download('punkt')
from nltk.corpus import stopwords
stopword = stopwords.words('english')
print(stopword)

stemmer = PorterStemmer()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %% [markdown]
# ### Cleaning the text data for any special characters and numerical characters

# %%
def testpreprocess(phrase):
    phrase = re.sub('[^A-Za-z0-9]+', ' ', phrase)
    phrase = re.sub(r'\w*\d\w*', '', phrase).strip()
    return phrase

# %%
preprocessed_excerpt = []
for sentence in tqdm(df_train['excerpt'].values):
  sent = testpreprocess(sentence)
  sent = sent.lower().strip()
  sent = ' '.join(stemmer.stem(i) for i in sent.split(" "))
  sent = ' '.join(e for e in sent.split(" ") if e not in stopword)
  preprocessed_excerpt.append(sent)

df_train['cleaned_excerpt'] = preprocessed_excerpt
# Out:
# 100%|██████████| 2834/2834 [00:10<00:00, 277.69it/s]

# %% [markdown]
# ### Pretrained Glove Vector assignment

# %%
# Refer this for step by step method https://stackoverflow.com/questions/50060241/how-to-use-glove-word-embeddings-file-on-google-colaboratory

# !wget http://nlp.stanford.edu/data/glove.6B.zip # get the glove vector from stanford library

# %%
#unzip the downloaded glove vectors to drive
# !unzip glove*.zip

# %%
# creating the dictionary if word and vectors
print('Indexing word vectors.')

d_model = 300
glove_dict = {}
f = open('/content/drive/MyDrive/DeepLearning/Common Literacy/GloveVector/glove.6B.300d.txt', encoding='utf-8')
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    glove_dict[word] = coefs
f.close()

print('Found %s word vectors.' % len(glove_dict))

# checking the dictionary word shape
print(glove_dict['the'].shape)
# Out:
# Indexing word vectors.
# Found 400000 word vectors.
# (300,)

# %%
# creating a set of the keys from glove dictionary
glove_words = set(glove_dict.keys())

# %% [markdown]
# ### Pretrained Fast Text Vectors

# %%
# https://dl.fbaipublicfiles.com/fasttext/vectors-english/wiki-news-300d-1M.vec.zip

# creating the dictionary if word and vectors
print('Indexing word vectors.')

fasttext_dict = {}
f = open('/content/drive/MyDrive/DeepLearning/Common Literacy/FastText/wiki.simple.vec', encoding='utf-8')
for line in f:
  values = line.strip().rsplit(' ')
  word = values[0]
  coefs = np.asarray(values[1:], dtype='float32')
  fasttext_dict[word] = coefs
f.close()

print('Found %s word vectors.' % len(fasttext_dict))

# checking the dictionary word shape
print(fasttext_dict['the'].shape)
# Out:
# Indexing word vectors.
# Found 111024 word vectors.
# (300,)

# %%
# creating a set of the keys from glove dictionary
fasttext_words = set(fasttext_dict.keys())

# %% [markdown]
# ### Positional Encoding

# %%
import math
def positionalEncoding1DSine(max_sentence_length):
  positional_embeddings_sin = np.zeros(max_sentence_length)
  for position in range(max_sentence_length):
      positional_embeddings_sin[position] = (np.sin(position/(math.log(max_sentence_length))))
  return positional_embeddings_sin

def positionalEncoding1DCosine(max_sentence_length):
  positional_embeddings_cos = np.zeros(max_sentence_length)
  for position in range(max_sentence_length):
      positional_embeddings_cos[position] = (np.cos(position/(math.log(max_sentence_length))))
  return positional_embeddings_cos

def positionalEncoding1D(max_sentence_length):
  positional_embeddings_cos = np.zeros(max_sentence_length)
  positional_embeddings_sin = np.zeros(max_sentence_length)
  for position in range(max_sentence_length):
      positional_embeddings_cos[position] = (np.cos(position/(math.log(max_sentence_length))))
      positional_embeddings_sin[position] = (np.sin(position/(math.log(max_sentence_length))))
  positional_embeddings = np.add(positional_embeddings_cos, positional_embeddings_sin)
  return positional_embeddings

def positionalEncoding2d(max_sentence_length,d_model):
  positional_embeddings = np.zeros((max_sentence_length, d_model))
  for position in range(max_sentence_length):
      for i in range(0, d_model, 2):
        positional_embeddings[position, i] = (np.sin(position/(10000 ** ((2*i) / d_model))))
        positional_embeddings[position, i + 1] = (np.cos(position/(10000 ** ((2*(i+1)) / d_model))))
  return positional_embeddings

# %% [markdown]
# ### Glove Average Word 2 Vec With Glove Positional Encoding

# %%
def Avg_W2V_Pos(selfie): # give a pandas series into
  array_col_size = selfie.size
  AvgW2V_list = []; 
  for sentence in tqdm(selfie.values): 
      sentence = sentence.split()
      max_sentence_length = len(sentence)
      empty_vector = np.empty((0,d_model),dtype=float)
      posEmbed = positionalEncoding2d(max_sentence_length,d_model)
      for word in sentence:
          if word in glove_words: 
              vector = glove_dict[word] 
              vectorTranspose = np.reshape(vector,(-1,d_model))
              empty_vector = np.append(empty_vector,vectorTranspose,axis=0)
          else:
            vectorZeros = np.zeros((1,d_model),dtype=float)
            empty_vector = np.append(empty_vector,vectorZeros,axis=0)
      WordEmbedPOS = np.add(posEmbed, empty_vector)
      AvgW2V_list.append(WordEmbedPOS)
  # AvgW2V_Array = np.stack(AvgW2V_list, axis=0) # used to flatten the vector to one axis and convert the list of list to array
  return AvgW2V_list

# %% [markdown]
# ### Glove Average Word 2 Vec With Glove and FastText Positional Encoding

# %%
def Avg_W2V_Pos_Concat(selfie): # give a pandas series into
  array_col_size = selfie.size
  AvgW2V_list = []; 
  for sentence in tqdm(selfie.values): 
      sentence = sentence.split()
      max_sentence_length = len(sentence)
      empty_vector_glove = np.empty((0,d_model),dtype=float)
      empty_vector_fasttext = np.empty((0,d_model),dtype=float)
      posEmbed = positionalEncoding2d(max_sentence_length,d_model)
      for word in sentence:
          if word in glove_words: 
              vector_glove = glove_dict[word] 
              vectorTranspose_glove = np.reshape(vector_glove,(-1,d_model))
              empty_vector_glove = np.append(empty_vector_glove,vectorTranspose_glove,axis=0)
          else:
            vectorZeros_glove = np.zeros((1,d_model),dtype=float)
            empty_vector_glove = np.append(empty_vector_glove,vectorZeros_glove,axis=0)

          if word in fasttext_words: 
              vector_fasttext = fasttext_dict[word] 
              vectorTranspose_fasttext = np.reshape(vector_fasttext,(-1,d_model))
              empty_vector_fasttext = np.append(empty_vector_fasttext,vectorTranspose_fasttext,axis=0)
          else:
            vectorZeros_fasttext = np.zeros((1,d_model),dtype=float)
            empty_vector_fasttext = np.append(empty_vector_fasttext,vectorZeros_fasttext,axis=0)
      
      WordEmbed_Glove = np.add(posEmbed, empty_vector_glove)
      WordEmbed_Fasttext = np.add(posEmbed, empty_vector_fasttext)
      WordEmbedPOS = np.hstack((WordEmbed_Glove, WordEmbed_Fasttext))

      AvgW2V_list.append(WordEmbedPOS)
  # AvgW2V_Array = np.stack(AvgW2V_list, axis=0) # used to flatten the vector to one axis and convert the list of list to array
  return AvgW2V_list

# %% [markdown]
# ### Global TF-IDF Avg Word 2 Vec with Glove Positional Embedding

# %%
def Tfidf_Avg_W2V_Pos(selfie):
  tfidf_model = TfidfVectorizer()
  tfidf_model.fit(selfie)
  # we are converting a dictionary with word as a key, and the idf as a value
  dictionary = dict(zip(tfidf_model.get_feature_names(), list(tfidf_model.idf_)))
  tfidf_words = set(tfidf_model.get_feature_names())

  tfidf_w2v_vectors = []
  for sentence in tqdm(selfie.values): 
    sentence = sentence.split()
    max_sentence_length = len(sentence)
    empty_vector = np.empty((0,d_model),dtype=float)
    posEmbed = positionalEncoding2d(max_sentence_length,d_model)
    tf_idf_weight = 0
    for word in sentence:
      if (word in glove_words) and (word in tfidf_words):
        vector = glove_dict[word]
        tf_idf = dictionary[word]*(sentence.count(word)/len(sentence)) # here we are multiplying idf value(dictionary[word]) and the tf value((sentence.count(word)/len(sentence.split())))
        vector_Tfidf = (vector * tf_idf) # calculating tfidf weighted w2v
        vectorTranspose = np.reshape(vector_Tfidf,(-1,d_model))
        empty_vector = np.append(empty_vector,vectorTranspose,axis=0)
      else:
        vectorZeros = np.zeros((1,d_model),dtype=float)
        empty_vector = np.append(empty_vector,vectorZeros,axis=0)
    WordEmbedPOS = np.add(posEmbed, empty_vector)
    tfidf_w2v_vectors.append(WordEmbedPOS)
  #tfidf_w2v_vectors_Array = np.stack(tfidf_w2v_vectors, axis=0) # used to flatten the vector to one axis and convert the list of list to array
  return tfidf_w2v_vectors

# %% [markdown]
# ### Splitting data into Train and cross validation(or test): Stratified Sampling

# %%
Y = df_train['target']
# X = df_train['cleaned_excerpt']
X = df_train['excerpt']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.33)

# %%
print(X_train[0:3])
# Out:
# 1371    Then the causes of the war are summed up and t...
# 1712    The tube that communicates with the vessel, F,...
# 33      Katie Haydon is going to London, ma'am. Did sh...
# Name: excerpt, dtype: object

# %% [markdown]
# ### Word to Vector Representation

# %%
X_train_excerpt_w2v = Avg_W2V_Pos(X_train)
X_test_excerpt_w2v = Avg_W2V_Pos(X_test)
# Out:
# 100%|██████████| 1898/1898 [02:15<00:00, 13.96it/s]
# 100%|██████████| 936/936 [01:07<00:00, 13.90it/s]

# %% [markdown]
# ### Word to Vector Representation with Glove Fasttext Concat

# %%
X_train_excerpt_w2v_concat = Avg_W2V_Pos_Concat(X_train)
X_test_excerpt_w2v_concat = Avg_W2V_Pos_Concat(X_test)
# Out:
# 100%|██████████| 1898/1898 [02:28<00:00, 12.79it/s]
# 100%|██████████| 936/936 [01:14<00:00, 12.56it/s]

# %% [markdown]
# ### TFIDF Word to Vector Representation

# %%
X_train_excerpt_tfidf_w2v = Tfidf_Avg_W2V_Pos(X_train)
X_test_excerpt_tfidf_w2v = Tfidf_Avg_W2V_Pos(X_test)
# Out:
# 100%|██████████| 1898/1898 [02:20<00:00, 13.56it/s]
# 100%|██████████| 936/936 [01:08<00:00, 13.65it/s]

# %% [markdown]
# ### Padding Sequences

# %%
# adding padding to the text sequences
train_data_w2v_pos = pad_sequences(X_train_excerpt_w2v, maxlen=200)
test_data_w2v_pos = pad_sequences(X_test_excerpt_w2v,maxlen=200)

# %%
# adding padding to the text sequences
train_data_w2v_pos_concat = pad_sequences(X_train_excerpt_w2v_concat, maxlen=200)
test_data_w2v_pos_concat = pad_sequences(X_test_excerpt_w2v_concat,maxlen=200)

# %%
# adding padding to the text sequences
train_data_tfidf_w2v_pos = pad_sequences(X_train_excerpt_tfidf_w2v, maxlen=200)
test_data_tfidf_w2v_pos = pad_sequences(X_test_excerpt_tfidf_w2v,maxlen=200)

# %%
print(train_data_w2v_pos.shape)
print(test_data_w2v_pos.shape)
# Out:
# (1898, 200, 300)
# (936, 200, 300)

# %%
print(train_data_w2v_pos_concat.shape)
print(test_data_w2v_pos_concat.shape)
# Out:
# (1898, 200, 600)
# (936, 200, 600)

# %%
print(train_data_tfidf_w2v_pos.shape)
print(test_data_tfidf_w2v_pos.shape)
# Out:
# (1898, 200, 300)
# (936, 200, 300)

# %%
# Convert target to array
Y_train = np.asarray(Y_train)
Y_test = np.asarray(Y_test)

# %% [markdown]
# ### Model Definition

# %%
# Vocab_Size = 25000 # this is the total number of words being sent
# Word_Embedding_Size = 100 # this value is coming from Glove Vector Size
# Input_Sequence = 150 # this is based on the padding we have given

# %%
# from sklearn import metrics

# Y_pred_test = regressor.predict(test_data)
# test_residuals = Y_test - Y_pred_test
# mse_test = metrics.mean_squared_error(Y_test,Y_pred_test)

# %%
# print("Root Mean squared Error Test:",np.sqrt(mse_test))

# %% [markdown]
# ### Convolution Neural Network 1D

# %%
classifier = Sequential()

# Adding a first convolutional layer with Max pooling
classifier.add(Conv1D(1800, 5, padding = 'same', activation = 'relu', input_shape = (200, 600))),
classifier.add(AveragePooling1D(pool_size=5))
classifier.add(Dropout(0.8))

# MaxPool1D, GlobalMaxPooling1D, GlobalAveragePooling1D

# Step 3 Adding a first convolutional layer with Max pooling
classifier.add(Conv1D(600, 5, padding = 'same', activation = 'relu')),
classifier.add(AveragePooling1D(pool_size=5))
classifier.add(Dropout(0.5))

classifier.add(Bidirectional(LSTM(600)))

# Step 3 - Flattening
classifier.add(Flatten())

# Step 5 - Full connection layer with sigmoid
classifier.add(Dense(256, activation = 'relu'))
classifier.add(Dense(128, activation = 'relu'))
classifier.add(Dense(1, activation = 'linear'))

# Compiling the CNN
classifier.compile(optimizer = 'adam', loss = 'mse', metrics=['mse'])
classifier.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_6 (Conv1D)            (None, 200, 1800)         5401800
# _________________________________________________________________
# average_pooling1d_3 (Average (None, 40, 1800)          0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 40, 1800)          0
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 40, 600)           5400600
# _________________________________________________________________
# average_pooling1d_4 (Average (None, 8, 600)            0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 8, 600)            0
# _________________________________________________________________
# bidirectional_3 (Bidirection (None, 1200)              5764800
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1200)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               307456
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 16,907,681
# Trainable params: 16,907,681
# Non-trainable params: 0
# _________________________________________________________________

# %%
classifier.fit(train_data_w2v_pos_concat, Y_train, batch_size=200, epochs=500, validation_split=0.2, verbose=2)
# Out:
# Epoch 1/500
# 8/8 - 2s - loss: 0.4553 - mse: 0.4553 - val_loss: 0.5471 - val_mse: 0.5471
# Epoch 2/500
# 8/8 - 2s - loss: 0.4563 - mse: 0.4563 - val_loss: 0.4858 - val_mse: 0.4858
# Epoch 3/500
# 8/8 - 2s - loss: 0.4005 - mse: 0.4005 - val_loss: 0.4902 - val_mse: 0.4902
# Epoch 4/500
# 8/8 - 2s - loss: 0.4070 - mse: 0.4070 - val_loss: 0.5185 - val_mse: 0.5185
# Epoch 5/500
# 8/8 - 2s - loss: 0.3799 - mse: 0.3799 - val_loss: 0.4790 - val_mse: 0.4790
# Epoch 6/500
# 8/8 - 2s - loss: 0.3740 - mse: 0.3740 - val_loss: 0.4772 - val_mse: 0.4772
# Epoch 7/500
# 8/8 - 2s - loss: 0.3556 - mse: 0.3556 - val_loss: 0.5701 - val_mse: 0.5701
# Epoch 8/500
# 8/8 - 2s - loss: 0.4044 - mse: 0.4044 - val_loss: 0.4965 - val_mse: 0.4965
# Epoch 9/500
# 8/8 - 2s - loss: 0.3566 - mse: 0.3566 - val_loss: 0.4890 - val_mse: 0.4890
# Epoch 10/500
# 8/8 - 2s - loss: 0.3504 - mse: 0.3504 - val_loss: 0.5551 - val_mse: 0.5551
# Epoch 11/500
# 8/8 - 2s - loss: 0.3761 - mse: 0.3761 - val_loss: 0.4730 - val_mse: 0.4730
# Epoch 12/500
# 8/8 - 2s - loss: 0.3341 - mse: 0.3341 - val_loss: 0.4891 - val_mse: 0.4891
# Epoch 13/500
# 8/8 - 2s - loss: 0.3268 - mse: 0.3268 - val_loss: 0.5095 - val_mse: 0.5095
# Epoch 14/500
# 8/8 - 2s - loss: 0.3297 - mse: 0.3297 - val_loss: 0.5689 - val_mse: 0.5689
# Epoch 15/500
# 8/8 - 2s - loss: 0.3266 - mse: 0.3266 - val_loss: 0.4704 - val_mse: 0.4704
# Epoch 16/500
# 8/8 - 2s - loss: 0.2999 - mse: 0.2999 - val_loss: 0.5244 - val_mse: 0.5244
# Epoch 17/500
# 8/8 - 2s - loss: 0.3119 - mse: 0.3119 - val_loss: 0.4705 - val_mse: 0.4705
# Epoch 18/500
# 8/8 - 2s - loss: 0.4893 - mse: 0.4893 - val_loss: 0.5979 - val_mse: 0.5979
# Epoch 19/500
# 8/8 - 2s - loss: 0.4208 - mse: 0.4208 - val_loss: 0.5379 - val_mse: 0.5379
# Epoch 20/500
# 8/8 - 2s - loss: 0.3460 - mse: 0.3460 - val_loss: 0.5651 - val_mse: 0.5651
# Epoch 21/500
# 8/8 - 2s - loss: 0.3280 - mse: 0.3280 - val_loss: 0.5214 - val_mse: 0.5214
# Epoch 22/500
# 8/8 - 2s - loss: 0.3245 - mse: 0.3245 - val_loss: 0.5744 - val_mse: 0.5744
# Epoch 23/500
# 8/8 - 2s - loss: 0.3395 - mse: 0.3395 - val_loss: 0.5316 - val_mse: 0.5316
# Epoch 24/500
# 8/8 - 2s - loss: 0.2885 - mse: 0.2885 - val_loss: 0.4926 - val_mse: 0.4926
# Epoch 25/500
# 8/8 - 2s - loss: 0.2627 - mse: 0.2627 - val_loss: 0.4858 - val_mse: 0.4858
# Epoch 26/500
# 8/8 - 2s - loss: 0.2509 - mse: 0.2509 - val_loss: 0.4796 - val_mse: 0.4796
# Epoch 27/500
# 8/8 - 2s - loss: 0.3012 - mse: 0.3012 - val_loss: 0.4856 - val_mse: 0.4856
# Epoch 28/500
# 8/8 - 2s - loss: 0.2701 - mse: 0.2701 - val_loss: 0.5089 - val_mse: 0.5089
# Epoch 29/500
# 8/8 - 2s - loss: 0.2480 - mse: 0.2480 - val_loss: 0.4803 - val_mse: 0.4803
# Epoch 30/500
# 8/8 - 2s - loss: 0.2242 - mse: 0.2242 - val_loss: 0.4816 - val_mse: 0.4816
# Epoch 31/500
# 8/8 - 2s - loss: 0.2222 - mse: 0.2222 - val_loss: 0.5285 - val_mse: 0.5285
# Epoch 32/500
# 8/8 - 2s - loss: 0.3016 - mse: 0.3016 - val_loss: 0.5184 - val_mse: 0.5184
# Epoch 33/500
# 8/8 - 2s - loss: 0.2349 - mse: 0.2349 - val_loss: 0.4922 - val_mse: 0.4922
# Epoch 34/500
# 8/8 - 2s - loss: 0.2128 - mse: 0.2128 - val_loss: 0.4797 - val_mse: 0.4797
# Epoch 35/500
# 8/8 - 2s - loss: 0.2253 - mse: 0.2253 - val_loss: 0.4872 - val_mse: 0.4872
# Epoch 36/500
# 8/8 - 2s - loss: 0.2044 - mse: 0.2044 - val_loss: 0.4741 - val_mse: 0.4741
# Epoch 37/500
# 8/8 - 2s - loss: 0.1791 - mse: 0.1791 - val_loss: 0.4983 - val_mse: 0.4983
# Epoch 38/500
# 8/8 - 2s - loss: 0.1822 - mse: 0.1822 - val_loss: 0.4965 - val_mse: 0.4965
# Epoch 39/500
# 8/8 - 2s - loss: 0.1937 - mse: 0.1937 - val_loss: 0.4933 - val_mse: 0.4933
# Epoch 40/500
# 8/8 - 2s - loss: 0.1880 - mse: 0.1880 - val_loss: 0.5651 - val_mse: 0.5651
# Epoch 41/500
# 8/8 - 2s - loss: 0.1761 - mse: 0.1761 - val_loss: 0.5405 - val_mse: 0.5405
# Epoch 42/500
# 8/8 - 2s - loss: 0.1780 - mse: 0.1780 - val_loss: 0.4923 - val_mse: 0.4923
# Epoch 43/500
# 8/8 - 2s - loss: 0.1490 - mse: 0.1490 - val_loss: 0.5245 - val_mse: 0.5245
# Epoch 44/500
# 8/8 - 2s - loss: 0.1690 - mse: 0.1690 - val_loss: 0.4882 - val_mse: 0.4882
# Epoch 45/500
# 8/8 - 2s - loss: 0.1353 - mse: 0.1353 - val_loss: 0.4826 - val_mse: 0.4826
# Epoch 46/500
# 8/8 - 2s - loss: 0.1443 - mse: 0.1443 - val_loss: 0.5461 - val_mse: 0.5461
# Epoch 47/500
# 8/8 - 2s - loss: 0.1862 - mse: 0.1862 - val_loss: 0.4976 - val_mse: 0.4976
# Epoch 48/500
# 8/8 - 2s - loss: 0.2129 - mse: 0.2129 - val_loss: 0.5097 - val_mse: 0.5097
# Epoch 49/500
# 8/8 - 2s - loss: 0.1708 - mse: 0.1708 - val_loss: 0.4887 - val_mse: 0.4887
# Epoch 50/500
# 8/8 - 2s - loss: 0.1495 - mse: 0.1495 - val_loss: 0.4922 - val_mse: 0.4922
# Epoch 51/500
# 8/8 - 2s - loss: 0.1407 - mse: 0.1407 - val_loss: 0.4970 - val_mse: 0.4970
# Epoch 52/500
# 8/8 - 2s - loss: 0.1253 - mse: 0.1253 - val_loss: 0.5014 - val_mse: 0.5014
# Epoch 53/500
# 8/8 - 2s - loss: 0.1397 - mse: 0.1397 - val_loss: 0.4978 - val_mse: 0.4978
# Epoch 54/500
# 8/8 - 2s - loss: 0.1650 - mse: 0.1650 - val_loss: 0.4836 - val_mse: 0.4836
# Epoch 55/500
# 8/8 - 2s - loss: 0.1427 - mse: 0.1427 - val_loss: 0.4879 - val_mse: 0.4879
# Epoch 56/500
# 8/8 - 2s - loss: 0.1335 - mse: 0.1335 - val_loss: 0.5139 - val_mse: 0.5139
# Epoch 57/500
# 8/8 - 2s - loss: 0.1171 - mse: 0.1171 - val_loss: 0.4901 - val_mse: 0.4901
# Epoch 58/500
# 8/8 - 2s - loss: 0.1052 - mse: 0.1052 - val_loss: 0.4920 - val_mse: 0.4920
# Epoch 59/500
# 8/8 - 2s - loss: 0.1080 - mse: 0.1080 - val_loss: 0.5322 - val_mse: 0.5322
# Epoch 60/500
# 8/8 - 2s - loss: 0.1054 - mse: 0.1054 - val_loss: 0.5090 - val_mse: 0.5090
# Epoch 61/500
# 8/8 - 2s - loss: 0.0984 - mse: 0.0984 - val_loss: 0.4847 - val_mse: 0.4847
# Epoch 62/500
# 8/8 - 2s - loss: 0.0826 - mse: 0.0826 - val_loss: 0.4835 - val_mse: 0.4835
# Epoch 63/500
# 8/8 - 2s - loss: 0.0856 - mse: 0.0856 - val_loss: 0.5197 - val_mse: 0.5197
# Epoch 64/500
# 8/8 - 2s - loss: 0.1043 - mse: 0.1043 - val_loss: 0.4947 - val_mse: 0.4947
# Epoch 65/500
# 8/8 - 2s - loss: 0.0936 - mse: 0.0936 - val_loss: 0.4893 - val_mse: 0.4893
# Epoch 66/500
# 8/8 - 2s - loss: 0.0754 - mse: 0.0754 - val_loss: 0.4961 - val_mse: 0.4961
# Epoch 67/500
# 8/8 - 2s - loss: 0.0744 - mse: 0.0744 - val_loss: 0.5008 - val_mse: 0.5008
# Epoch 68/500
# 8/8 - 2s - loss: 0.0740 - mse: 0.0740 - val_loss: 0.5277 - val_mse: 0.5277
# Epoch 69/500
# 8/8 - 2s - loss: 0.0836 - mse: 0.0836 - val_loss: 0.4935 - val_mse: 0.4935
# Epoch 70/500
# 8/8 - 2s - loss: 0.0878 - mse: 0.0878 - val_loss: 0.5051 - val_mse: 0.5051
# Epoch 71/500
# 8/8 - 2s - loss: 0.0755 - mse: 0.0755 - val_loss: 0.4994 - val_mse: 0.4994
# Epoch 72/500
# 8/8 - 2s - loss: 0.0746 - mse: 0.0746 - val_loss: 0.5000 - val_mse: 0.5000
# Epoch 73/500
# 8/8 - 2s - loss: 0.0687 - mse: 0.0687 - val_loss: 0.4925 - val_mse: 0.4925
# Epoch 74/500
# 8/8 - 2s - loss: 0.0668 - mse: 0.0668 - val_loss: 0.4843 - val_mse: 0.4843
# Epoch 75/500
# 8/8 - 2s - loss: 0.0677 - mse: 0.0677 - val_loss: 0.4871 - val_mse: 0.4871
# Epoch 76/500
# 8/8 - 2s - loss: 0.0680 - mse: 0.0680 - val_loss: 0.5000 - val_mse: 0.5000
# Epoch 77/500
# 8/8 - 2s - loss: 0.0739 - mse: 0.0739 - val_loss: 0.4775 - val_mse: 0.4775
# Epoch 78/500
# 8/8 - 2s - loss: 0.0635 - mse: 0.0635 - val_loss: 0.4955 - val_mse: 0.4955
# Epoch 79/500
# 8/8 - 2s - loss: 0.0612 - mse: 0.0612 - val_loss: 0.5000 - val_mse: 0.5000
# Epoch 80/500
# 8/8 - 2s - loss: 0.0691 - mse: 0.0691 - val_loss: 0.5202 - val_mse: 0.5202
# Epoch 81/500
# 8/8 - 2s - loss: 0.0645 - mse: 0.0645 - val_loss: 0.5151 - val_mse: 0.5151
# Epoch 82/500
# 8/8 - 2s - loss: 0.0593 - mse: 0.0593 - val_loss: 0.5002 - val_mse: 0.5002
# Epoch 83/500
# 8/8 - 2s - loss: 0.0672 - mse: 0.0672 - val_loss: 0.4871 - val_mse: 0.4871
# Epoch 84/500
# 8/8 - 2s - loss: 0.0586 - mse: 0.0586 - val_loss: 0.4900 - val_mse: 0.4900
# Epoch 85/500
# 8/8 - 2s - loss: 0.0624 - mse: 0.0624 - val_loss: 0.4975 - val_mse: 0.4975
# Epoch 86/500
# 8/8 - 2s - loss: 0.0532 - mse: 0.0532 - val_loss: 0.4870 - val_mse: 0.4870
# Epoch 87/500
# 8/8 - 2s - loss: 0.0541 - mse: 0.0541 - val_loss: 0.5084 - val_mse: 0.5084
# Epoch 88/500
# 8/8 - 2s - loss: 0.0611 - mse: 0.0611 - val_loss: 0.5139 - val_mse: 0.5139
# Epoch 89/500
# 8/8 - 2s - loss: 0.0670 - mse: 0.0670 - val_loss: 0.5042 - val_mse: 0.5042
# Epoch 90/500
# 8/8 - 2s - loss: 0.0694 - mse: 0.0694 - val_loss: 0.4902 - val_mse: 0.4902
# Epoch 91/500
# 8/8 - 2s - loss: 0.0595 - mse: 0.0595 - val_loss: 0.4899 - val_mse: 0.4899
# Epoch 92/500
# 8/8 - 2s - loss: 0.0712 - mse: 0.0712 - val_loss: 0.5313 - val_mse: 0.5313
# Epoch 93/500
# 8/8 - 2s - loss: 0.0707 - mse: 0.0707 - val_loss: 0.4932 - val_mse: 0.4932
# Epoch 94/500
# 8/8 - 2s - loss: 0.0557 - mse: 0.0557 - val_loss: 0.4959 - val_mse: 0.4959
# Epoch 95/500
# 8/8 - 2s - loss: 0.0529 - mse: 0.0529 - val_loss: 0.4858 - val_mse: 0.4858
# Epoch 96/500
# 8/8 - 2s - loss: 0.0583 - mse: 0.0583 - val_loss: 0.5283 - val_mse: 0.5283
# Epoch 97/500
# 8/8 - 2s - loss: 0.0702 - mse: 0.0702 - val_loss: 0.5385 - val_mse: 0.5385
# Epoch 98/500
# 8/8 - 2s - loss: 0.0672 - mse: 0.0672 - val_loss: 0.4857 - val_mse: 0.4857
# Epoch 99/500
# 8/8 - 2s - loss: 0.0482 - mse: 0.0482 - val_loss: 0.4955 - val_mse: 0.4955
# Epoch 100/500
# 8/8 - 2s - loss: 0.0455 - mse: 0.0455 - val_loss: 0.4808 - val_mse: 0.4808
# Epoch 101/500
# 8/8 - 2s - loss: 0.0474 - mse: 0.0474 - val_loss: 0.5128 - val_mse: 0.5128
# Epoch 102/500
# 8/8 - 2s - loss: 0.0515 - mse: 0.0515 - val_loss: 0.4888 - val_mse: 0.4888
# Epoch 103/500
# 8/8 - 2s - loss: 0.0438 - mse: 0.0438 - val_loss: 0.4917 - val_mse: 0.4917
# Epoch 104/500
# 8/8 - 2s - loss: 0.0447 - mse: 0.0447 - val_loss: 0.4852 - val_mse: 0.4852
# Epoch 105/500
# 8/8 - 2s - loss: 0.0438 - mse: 0.0438 - val_loss: 0.4896 - val_mse: 0.4896
# Epoch 106/500
# 8/8 - 2s - loss: 0.0432 - mse: 0.0432 - val_loss: 0.4942 - val_mse: 0.4942
# Epoch 107/500
# 8/8 - 2s - loss: 0.0456 - mse: 0.0456 - val_loss: 0.4943 - val_mse: 0.4943
# Epoch 108/500
# 8/8 - 2s - loss: 0.0470 - mse: 0.0470 - val_loss: 0.4880 - val_mse: 0.4880
# Epoch 109/500
# 8/8 - 2s - loss: 0.0425 - mse: 0.0425 - val_loss: 0.4855 - val_mse: 0.4855
# Epoch 110/500
# 8/8 - 2s - loss: 0.0489 - mse: 0.0489 - val_loss: 0.4954 - val_mse: 0.4954
# Epoch 111/500
# 8/8 - 2s - loss: 0.0416 - mse: 0.0416 - val_loss: 0.4933 - val_mse: 0.4933
# Epoch 112/500
# 8/8 - 2s - loss: 0.0410 - mse: 0.0410 - val_loss: 0.4897 - val_mse: 0.4897
# Epoch 113/500
# 8/8 - 2s - loss: 0.0374 - mse: 0.0374 - val_loss: 0.4978 - val_mse: 0.4978
# Epoch 114/500
# 8/8 - 2s - loss: 0.0502 - mse: 0.0502 - val_loss: 0.4868 - val_mse: 0.4868
# Epoch 115/500
# 8/8 - 2s - loss: 0.0516 - mse: 0.0516 - val_loss: 0.4826 - val_mse: 0.4826
# Epoch 116/500
# 8/8 - 2s - loss: 0.0452 - mse: 0.0452 - val_loss: 0.5015 - val_mse: 0.5015
# Epoch 117/500
# 8/8 - 2s - loss: 0.0433 - mse: 0.0433 - val_loss: 0.4965 - val_mse: 0.4965
# Epoch 118/500
# 8/8 - 2s - loss: 0.0392 - mse: 0.0392 - val_loss: 0.5017 - val_mse: 0.5017
# Epoch 119/500
# 8/8 - 2s - loss: 0.0437 - mse: 0.0437 - val_loss: 0.4839 - val_mse: 0.4839
# Epoch 120/500
# 8/8 - 2s - loss: 0.0349 - mse: 0.0349 - val_loss: 0.4911 - val_mse: 0.4911
# Epoch 121/500
# 8/8 - 2s - loss: 0.0516 - mse: 0.0516 - val_loss: 0.5216 - val_mse: 0.5216
# Epoch 122/500
# 8/8 - 2s - loss: 0.0517 - mse: 0.0517 - val_loss: 0.5262 - val_mse: 0.5262
# Epoch 123/500
# 8/8 - 2s - loss: 0.0427 - mse: 0.0427 - val_loss: 0.4844 - val_mse: 0.4844
# Epoch 124/500
# 8/8 - 2s - loss: 0.0344 - mse: 0.0344 - val_loss: 0.4883 - val_mse: 0.4883
# Epoch 125/500
# 8/8 - 2s - loss: 0.0373 - mse: 0.0373 - val_loss: 0.4876 - val_mse: 0.4876
# Epoch 126/500
# 8/8 - 2s - loss: 0.0369 - mse: 0.0369 - val_loss: 0.4867 - val_mse: 0.4867
# Epoch 127/500
# 8/8 - 2s - loss: 0.0340 - mse: 0.0340 - val_loss: 0.4955 - val_mse: 0.4955
# Epoch 128/500
# 8/8 - 2s - loss: 0.0367 - mse: 0.0367 - val_loss: 0.4882 - val_mse: 0.4882
# Epoch 129/500
# 8/8 - 2s - loss: 0.0369 - mse: 0.0369 - val_loss: 0.4967 - val_mse: 0.4967
# Epoch 130/500
# 8/8 - 2s - loss: 0.0354 - mse: 0.0354 - val_loss: 0.5066 - val_mse: 0.5066
# Epoch 131/500
# 8/8 - 2s - loss: 0.0372 - mse: 0.0372 - val_loss: 0.4897 - val_mse: 0.4897
# Epoch 132/500
# 8/8 - 2s - loss: 0.0377 - mse: 0.0377 - val_loss: 0.4853 - val_mse: 0.4853
# Epoch 133/500
# 8/8 - 2s - loss: 0.0327 - mse: 0.0327 - val_loss: 0.4855 - val_mse: 0.4855
# Epoch 134/500
# 8/8 - 2s - loss: 0.0337 - mse: 0.0337 - val_loss: 0.4836 - val_mse: 0.4836
# Epoch 135/500
# 8/8 - 2s - loss: 0.0324 - mse: 0.0324 - val_loss: 0.4939 - val_mse: 0.4939
# Epoch 136/500
# 8/8 - 2s - loss: 0.0321 - mse: 0.0321 - val_loss: 0.4827 - val_mse: 0.4827
# Epoch 137/500
# 8/8 - 2s - loss: 0.0389 - mse: 0.0389 - val_loss: 0.5028 - val_mse: 0.5028
# Epoch 138/500
# 8/8 - 2s - loss: 0.0408 - mse: 0.0408 - val_loss: 0.4886 - val_mse: 0.4886
# Epoch 139/500
# 8/8 - 2s - loss: 0.0329 - mse: 0.0329 - val_loss: 0.4873 - val_mse: 0.4873
# Epoch 140/500
# 8/8 - 2s - loss: 0.0328 - mse: 0.0328 - val_loss: 0.4880 - val_mse: 0.4880
# Epoch 141/500
# 8/8 - 2s - loss: 0.0370 - mse: 0.0370 - val_loss: 0.5132 - val_mse: 0.5132
# Epoch 142/500
# 8/8 - 2s - loss: 0.0408 - mse: 0.0408 - val_loss: 0.4849 - val_mse: 0.4849
# Epoch 143/500
# 8/8 - 2s - loss: 0.0317 - mse: 0.0317 - val_loss: 0.4821 - val_mse: 0.4821
# Epoch 144/500
# 8/8 - 2s - loss: 0.0336 - mse: 0.0336 - val_loss: 0.4972 - val_mse: 0.4972
# Epoch 145/500
# 8/8 - 2s - loss: 0.0339 - mse: 0.0339 - val_loss: 0.4851 - val_mse: 0.4851
# Epoch 146/500
# 8/8 - 2s - loss: 0.0365 - mse: 0.0365 - val_loss: 0.4869 - val_mse: 0.4869
# Epoch 147/500
# 8/8 - 2s - loss: 0.0283 - mse: 0.0283 - val_loss: 0.4914 - val_mse: 0.4914
# Epoch 148/500
# 8/8 - 2s - loss: 0.0341 - mse: 0.0341 - val_loss: 0.4910 - val_mse: 0.4910
# Epoch 149/500
# 8/8 - 2s - loss: 0.0290 - mse: 0.0290 - val_loss: 0.4838 - val_mse: 0.4838
# Epoch 150/500
# 8/8 - 2s - loss: 0.0285 - mse: 0.0285 - val_loss: 0.4871 - val_mse: 0.4871
# Epoch 151/500
# 8/8 - 2s - loss: 0.0334 - mse: 0.0334 - val_loss: 0.4801 - val_mse: 0.4801
# Epoch 152/500
# 8/8 - 2s - loss: 0.0280 - mse: 0.0280 - val_loss: 0.4860 - val_mse: 0.4860
# Epoch 153/500
# 8/8 - 2s - loss: 0.0311 - mse: 0.0311 - val_loss: 0.4838 - val_mse: 0.4838
# Epoch 154/500
# 8/8 - 2s - loss: 0.0328 - mse: 0.0328 - val_loss: 0.4887 - val_mse: 0.4887
# Epoch 155/500
# 8/8 - 2s - loss: 0.0312 - mse: 0.0312 - val_loss: 0.4873 - val_mse: 0.4873
# Epoch 156/500
# 8/8 - 2s - loss: 0.0288 - mse: 0.0288 - val_loss: 0.4904 - val_mse: 0.4904
# Epoch 157/500
# 8/8 - 2s - loss: 0.0296 - mse: 0.0296 - val_loss: 0.4844 - val_mse: 0.4844
# Epoch 158/500
# 8/8 - 2s - loss: 0.0288 - mse: 0.0288 - val_loss: 0.4955 - val_mse: 0.4955
# Epoch 159/500
# 8/8 - 2s - loss: 0.0340 - mse: 0.0340 - val_loss: 0.4848 - val_mse: 0.4848
# Epoch 160/500
# 8/8 - 2s - loss: 0.0279 - mse: 0.0279 - val_loss: 0.4963 - val_mse: 0.4963
# Epoch 161/500
# 8/8 - 2s - loss: 0.0305 - mse: 0.0305 - val_loss: 0.4864 - val_mse: 0.4864
# Epoch 162/500
# 8/8 - 2s - loss: 0.0285 - mse: 0.0285 - val_loss: 0.4971 - val_mse: 0.4971
# Epoch 163/500
# 8/8 - 2s - loss: 0.0266 - mse: 0.0266 - val_loss: 0.4856 - val_mse: 0.4856
# Epoch 164/500
# 8/8 - 2s - loss: 0.0291 - mse: 0.0291 - val_loss: 0.4937 - val_mse: 0.4937
# Epoch 165/500
# 8/8 - 2s - loss: 0.0305 - mse: 0.0305 - val_loss: 0.4856 - val_mse: 0.4856
# Epoch 166/500
# 8/8 - 2s - loss: 0.0362 - mse: 0.0362 - val_loss: 0.4983 - val_mse: 0.4983
# Epoch 167/500
# 8/8 - 2s - loss: 0.0318 - mse: 0.0318 - val_loss: 0.4867 - val_mse: 0.4867
# Epoch 168/500
# 8/8 - 2s - loss: 0.0274 - mse: 0.0274 - val_loss: 0.4870 - val_mse: 0.4870
# Epoch 169/500
# 8/8 - 2s - loss: 0.0270 - mse: 0.0270 - val_loss: 0.4934 - val_mse: 0.4934
# Epoch 170/500
# 8/8 - 2s - loss: 0.0352 - mse: 0.0352 - val_loss: 0.4867 - val_mse: 0.4867
# Epoch 171/500
# 8/8 - 2s - loss: 0.0322 - mse: 0.0322 - val_loss: 0.4927 - val_mse: 0.4927
# Epoch 172/500
# 8/8 - 2s - loss: 0.0304 - mse: 0.0304 - val_loss: 0.4846 - val_mse: 0.4846
# Epoch 173/500
# 8/8 - 2s - loss: 0.0263 - mse: 0.0263 - val_loss: 0.4804 - val_mse: 0.4804
# Epoch 174/500
# 8/8 - 2s - loss: 0.0276 - mse: 0.0276 - val_loss: 0.4975 - val_mse: 0.4975
# Epoch 175/500
# 8/8 - 2s - loss: 0.0289 - mse: 0.0289 - val_loss: 0.4757 - val_mse: 0.4757
# Epoch 176/500
# 8/8 - 2s - loss: 0.0255 - mse: 0.0255 - val_loss: 0.4823 - val_mse: 0.4823
# Epoch 177/500
# 8/8 - 2s - loss: 0.0302 - mse: 0.0302 - val_loss: 0.4868 - val_mse: 0.4868
# Epoch 178/500
# 8/8 - 2s - loss: 0.0278 - mse: 0.0278 - val_loss: 0.4848 - val_mse: 0.4848
# Epoch 179/500
# 8/8 - 2s - loss: 0.0325 - mse: 0.0325 - val_loss: 0.4853 - val_mse: 0.4853
# Epoch 180/500
# 8/8 - 2s - loss: 0.0348 - mse: 0.0348 - val_loss: 0.4942 - val_mse: 0.4942
# Epoch 181/500
# 8/8 - 2s - loss: 0.0313 - mse: 0.0313 - val_loss: 0.4836 - val_mse: 0.4836
# Epoch 182/500
# 8/8 - 2s - loss: 0.0281 - mse: 0.0281 - val_loss: 0.4939 - val_mse: 0.4939
# Epoch 183/500
# 8/8 - 2s - loss: 0.0317 - mse: 0.0317 - val_loss: 0.4800 - val_mse: 0.4800
# Epoch 184/500
# 8/8 - 2s - loss: 0.0296 - mse: 0.0296 - val_loss: 0.4850 - val_mse: 0.4850
# Epoch 185/500
# 8/8 - 2s - loss: 0.0319 - mse: 0.0319 - val_loss: 0.4930 - val_mse: 0.4930
# Epoch 186/500
# 8/8 - 2s - loss: 0.0301 - mse: 0.0301 - val_loss: 0.4806 - val_mse: 0.4806
# Epoch 187/500
# 8/8 - 2s - loss: 0.0273 - mse: 0.0273 - val_loss: 0.4867 - val_mse: 0.4867
# Epoch 188/500
# 8/8 - 2s - loss: 0.0272 - mse: 0.0272 - val_loss: 0.4961 - val_mse: 0.4961
# Epoch 189/500
# 8/8 - 2s - loss: 0.0286 - mse: 0.0286 - val_loss: 0.4875 - val_mse: 0.4875
# Epoch 190/500
# 8/8 - 2s - loss: 0.0273 - mse: 0.0273 - val_loss: 0.4825 - val_mse: 0.4825
# Epoch 191/500
# 8/8 - 2s - loss: 0.0262 - mse: 0.0262 - val_loss: 0.4834 - val_mse: 0.4834
# Epoch 192/500
# 8/8 - 2s - loss: 0.0274 - mse: 0.0274 - val_loss: 0.4777 - val_mse: 0.4777
# Epoch 193/500
# 8/8 - 2s - loss: 0.0298 - mse: 0.0298 - val_loss: 0.4802 - val_mse: 0.4802
# Epoch 194/500
# 8/8 - 2s - loss: 0.0262 - mse: 0.0262 - val_loss: 0.4868 - val_mse: 0.4868
# Epoch 195/500
# 8/8 - 2s - loss: 0.0258 - mse: 0.0258 - val_loss: 0.4931 - val_mse: 0.4931
# Epoch 196/500
# 8/8 - 2s - loss: 0.0274 - mse: 0.0274 - val_loss: 0.4898 - val_mse: 0.4898
# Epoch 197/500
# 8/8 - 2s - loss: 0.0268 - mse: 0.0268 - val_loss: 0.4839 - val_mse: 0.4839
# Epoch 198/500
# 8/8 - 2s - loss: 0.0230 - mse: 0.0230 - val_loss: 0.4849 - val_mse: 0.4849
# Epoch 199/500
# 8/8 - 2s - loss: 0.0230 - mse: 0.0230 - val_loss: 0.4830 - val_mse: 0.4830
# Epoch 200/500
# 8/8 - 2s - loss: 0.0240 - mse: 0.0240 - val_loss: 0.4827 - val_mse: 0.4827
# Epoch 201/500
# 8/8 - 2s - loss: 0.0240 - mse: 0.0240 - val_loss: 0.4857 - val_mse: 0.4857
# Epoch 202/500
# 8/8 - 2s - loss: 0.0315 - mse: 0.0315 - val_loss: 0.4809 - val_mse: 0.4809
# Epoch 203/500
# 8/8 - 2s - loss: 0.0235 - mse: 0.0235 - val_loss: 0.4803 - val_mse: 0.4803
# Epoch 204/500
# 8/8 - 2s - loss: 0.0231 - mse: 0.0231 - val_loss: 0.4886 - val_mse: 0.4886
# Epoch 205/500
# 8/8 - 2s - loss: 0.0255 - mse: 0.0255 - val_loss: 0.4833 - val_mse: 0.4833
# Epoch 206/500
# 8/8 - 2s - loss: 0.0247 - mse: 0.0247 - val_loss: 0.4810 - val_mse: 0.4810
# Epoch 207/500
# 8/8 - 2s - loss: 0.0294 - mse: 0.0294 - val_loss: 0.4925 - val_mse: 0.4925
# Epoch 208/500
# 8/8 - 2s - loss: 0.0282 - mse: 0.0282 - val_loss: 0.4978 - val_mse: 0.4978
# Epoch 209/500
# 8/8 - 2s - loss: 0.0281 - mse: 0.0281 - val_loss: 0.5199 - val_mse: 0.5199
# Epoch 210/500
# 8/8 - 2s - loss: 0.0332 - mse: 0.0332 - val_loss: 0.4795 - val_mse: 0.4795
# Epoch 211/500
# 8/8 - 2s - loss: 0.0270 - mse: 0.0270 - val_loss: 0.4855 - val_mse: 0.4855
# Epoch 212/500
# 8/8 - 2s - loss: 0.0256 - mse: 0.0256 - val_loss: 0.4846 - val_mse: 0.4846
# Epoch 213/500
# 8/8 - 2s - loss: 0.0241 - mse: 0.0241 - val_loss: 0.4815 - val_mse: 0.4815
# Epoch 214/500
# 8/8 - 2s - loss: 0.0214 - mse: 0.0214 - val_loss: 0.4763 - val_mse: 0.4763
# Epoch 215/500
# 8/8 - 2s - loss: 0.0223 - mse: 0.0223 - val_loss: 0.4890 - val_mse: 0.4890
# Epoch 216/500
# 8/8 - 2s - loss: 0.0244 - mse: 0.0244 - val_loss: 0.4795 - val_mse: 0.4795
# Epoch 217/500
# 8/8 - 2s - loss: 0.0204 - mse: 0.0204 - val_loss: 0.4804 - val_mse: 0.4804
# Epoch 218/500
# 8/8 - 2s - loss: 0.0229 - mse: 0.0229 - val_loss: 0.4774 - val_mse: 0.4774
# Epoch 219/500
# 8/8 - 2s - loss: 0.0211 - mse: 0.0211 - val_loss: 0.4919 - val_mse: 0.4919
# Epoch 220/500
# 8/8 - 2s - loss: 0.0249 - mse: 0.0249 - val_loss: 0.4845 - val_mse: 0.4845
# Epoch 221/500
# 8/8 - 2s - loss: 0.0228 - mse: 0.0228 - val_loss: 0.4856 - val_mse: 0.4856
# Epoch 222/500
# 8/8 - 2s - loss: 0.0240 - mse: 0.0240 - val_loss: 0.4768 - val_mse: 0.4768
# Epoch 223/500
# 8/8 - 2s - loss: 0.0264 - mse: 0.0264 - val_loss: 0.4755 - val_mse: 0.4755
# Epoch 224/500
# 8/8 - 2s - loss: 0.0225 - mse: 0.0225 - val_loss: 0.4870 - val_mse: 0.4870
# Epoch 225/500
# 8/8 - 2s - loss: 0.0221 - mse: 0.0221 - val_loss: 0.4925 - val_mse: 0.4925
# Epoch 226/500
# 8/8 - 2s - loss: 0.0287 - mse: 0.0287 - val_loss: 0.5013 - val_mse: 0.5013
# Epoch 227/500
# 8/8 - 2s - loss: 0.0282 - mse: 0.0282 - val_loss: 0.4839 - val_mse: 0.4839
# Epoch 228/500
# 8/8 - 2s - loss: 0.0220 - mse: 0.0220 - val_loss: 0.4780 - val_mse: 0.4780
# Epoch 229/500
# 8/8 - 2s - loss: 0.0202 - mse: 0.0202 - val_loss: 0.4804 - val_mse: 0.4804
# Epoch 230/500
# 8/8 - 2s - loss: 0.0217 - mse: 0.0217 - val_loss: 0.4870 - val_mse: 0.4870
# Epoch 231/500
# 8/8 - 2s - loss: 0.0206 - mse: 0.0206 - val_loss: 0.4808 - val_mse: 0.4808
# Epoch 232/500
# 8/8 - 2s - loss: 0.0197 - mse: 0.0197 - val_loss: 0.4884 - val_mse: 0.4884
# Epoch 233/500
# 8/8 - 2s - loss: 0.0218 - mse: 0.0218 - val_loss: 0.4852 - val_mse: 0.4852
# Epoch 234/500
# 8/8 - 2s - loss: 0.0259 - mse: 0.0259 - val_loss: 0.4805 - val_mse: 0.4805
# Epoch 235/500
# 8/8 - 2s - loss: 0.0238 - mse: 0.0238 - val_loss: 0.4781 - val_mse: 0.4781
# Epoch 236/500
# 8/8 - 2s - loss: 0.0226 - mse: 0.0226 - val_loss: 0.4764 - val_mse: 0.4764
# Epoch 237/500
# 8/8 - 2s - loss: 0.0232 - mse: 0.0232 - val_loss: 0.4900 - val_mse: 0.4900
# Epoch 238/500
# 8/8 - 2s - loss: 0.0211 - mse: 0.0211 - val_loss: 0.4903 - val_mse: 0.4903
# Epoch 239/500
# 8/8 - 2s - loss: 0.0218 - mse: 0.0218 - val_loss: 0.4833 - val_mse: 0.4833
# Epoch 240/500
# 8/8 - 2s - loss: 0.0196 - mse: 0.0196 - val_loss: 0.4795 - val_mse: 0.4795
# Epoch 241/500
# 8/8 - 2s - loss: 0.0202 - mse: 0.0202 - val_loss: 0.4725 - val_mse: 0.4725
# Epoch 242/500
# 8/8 - 2s - loss: 0.0196 - mse: 0.0196 - val_loss: 0.4761 - val_mse: 0.4761
# Epoch 243/500
# 8/8 - 2s - loss: 0.0224 - mse: 0.0224 - val_loss: 0.4909 - val_mse: 0.4909
# Epoch 244/500
# 8/8 - 2s - loss: 0.0219 - mse: 0.0219 - val_loss: 0.4703 - val_mse: 0.4703
# Epoch 245/500
# 8/8 - 2s - loss: 0.0212 - mse: 0.0212 - val_loss: 0.4794 - val_mse: 0.4794
# Epoch 246/500
# 8/8 - 2s - loss: 0.0221 - mse: 0.0221 - val_loss: 0.4785 - val_mse: 0.4785
# Epoch 247/500
# 8/8 - 2s - loss: 0.0217 - mse: 0.0217 - val_loss: 0.4779 - val_mse: 0.4779
# Epoch 248/500
# 8/8 - 2s - loss: 0.0204 - mse: 0.0204 - val_loss: 0.4880 - val_mse: 0.4880
# Epoch 249/500
# 8/8 - 2s - loss: 0.0212 - mse: 0.0212 - val_loss: 0.4798 - val_mse: 0.4798
# Epoch 250/500
# 8/8 - 2s - loss: 0.0251 - mse: 0.0251 - val_loss: 0.4801 - val_mse: 0.4801
# Epoch 251/500
# 8/8 - 2s - loss: 0.0209 - mse: 0.0209 - val_loss: 0.4803 - val_mse: 0.4803
# Epoch 252/500
# 8/8 - 2s - loss: 0.0195 - mse: 0.0195 - val_loss: 0.4838 - val_mse: 0.4838
# Epoch 253/500
# 8/8 - 2s - loss: 0.0213 - mse: 0.0213 - val_loss: 0.4849 - val_mse: 0.4849
# Epoch 254/500
# 8/8 - 2s - loss: 0.0197 - mse: 0.0197 - val_loss: 0.4861 - val_mse: 0.4861
# Epoch 255/500
# 8/8 - 2s - loss: 0.0195 - mse: 0.0195 - val_loss: 0.4825 - val_mse: 0.4825
# Epoch 256/500
# 8/8 - 2s - loss: 0.0186 - mse: 0.0186 - val_loss: 0.4800 - val_mse: 0.4800
# Epoch 257/500
# 8/8 - 2s - loss: 0.0210 - mse: 0.0210 - val_loss: 0.4749 - val_mse: 0.4749
# Epoch 258/500
# 8/8 - 2s - loss: 0.0214 - mse: 0.0214 - val_loss: 0.4818 - val_mse: 0.4818
# Epoch 259/500
# 8/8 - 2s - loss: 0.0219 - mse: 0.0219 - val_loss: 0.4838 - val_mse: 0.4838
# Epoch 260/500
# 8/8 - 2s - loss: 0.0219 - mse: 0.0219 - val_loss: 0.4929 - val_mse: 0.4929
# Epoch 261/500
# 8/8 - 2s - loss: 0.0216 - mse: 0.0216 - val_loss: 0.4963 - val_mse: 0.4963
# Epoch 262/500
# 8/8 - 2s - loss: 0.0222 - mse: 0.0222 - val_loss: 0.4936 - val_mse: 0.4936
# Epoch 263/500
# 8/8 - 2s - loss: 0.0212 - mse: 0.0212 - val_loss: 0.4844 - val_mse: 0.4844
# Epoch 264/500
# 8/8 - 2s - loss: 0.0206 - mse: 0.0206 - val_loss: 0.4724 - val_mse: 0.4724
# Epoch 265/500
# 8/8 - 2s - loss: 0.0252 - mse: 0.0252 - val_loss: 0.4731 - val_mse: 0.4731
# Epoch 266/500
# 8/8 - 2s - loss: 0.0270 - mse: 0.0270 - val_loss: 0.4807 - val_mse: 0.4807
# Epoch 267/500
# 8/8 - 2s - loss: 0.0204 - mse: 0.0204 - val_loss: 0.4858 - val_mse: 0.4858
# Epoch 268/500
# 8/8 - 2s - loss: 0.0200 - mse: 0.0200 - val_loss: 0.4832 - val_mse: 0.4832
# Epoch 269/500
# 8/8 - 2s - loss: 0.0188 - mse: 0.0188 - val_loss: 0.4885 - val_mse: 0.4885
# Epoch 270/500
# 8/8 - 2s - loss: 0.0217 - mse: 0.0217 - val_loss: 0.5040 - val_mse: 0.5040
# Epoch 271/500
# 8/8 - 2s - loss: 0.0222 - mse: 0.0222 - val_loss: 0.4834 - val_mse: 0.4834
# Epoch 272/500
# 8/8 - 2s - loss: 0.0192 - mse: 0.0192 - val_loss: 0.4766 - val_mse: 0.4766
# Epoch 273/500
# 8/8 - 2s - loss: 0.0220 - mse: 0.0220 - val_loss: 0.4826 - val_mse: 0.4826
# Epoch 274/500
# 8/8 - 2s - loss: 0.0195 - mse: 0.0195 - val_loss: 0.4746 - val_mse: 0.4746
# Epoch 275/500
# 8/8 - 2s - loss: 0.0194 - mse: 0.0194 - val_loss: 0.4811 - val_mse: 0.4811
# Epoch 276/500
# 8/8 - 2s - loss: 0.0181 - mse: 0.0181 - val_loss: 0.4747 - val_mse: 0.4747
# Epoch 277/500
# 8/8 - 2s - loss: 0.0183 - mse: 0.0183 - val_loss: 0.4784 - val_mse: 0.4784
# Epoch 278/500
# 8/8 - 2s - loss: 0.0195 - mse: 0.0195 - val_loss: 0.4781 - val_mse: 0.4781
# Epoch 279/500
# 8/8 - 2s - loss: 0.0177 - mse: 0.0177 - val_loss: 0.4872 - val_mse: 0.4872
# Epoch 280/500
# 8/8 - 2s - loss: 0.0190 - mse: 0.0190 - val_loss: 0.4854 - val_mse: 0.4854
# Epoch 281/500
# 8/8 - 2s - loss: 0.0218 - mse: 0.0218 - val_loss: 0.4775 - val_mse: 0.4775
# Epoch 282/500
# 8/8 - 2s - loss: 0.0212 - mse: 0.0212 - val_loss: 0.4772 - val_mse: 0.4772
# Epoch 283/500
# 8/8 - 2s - loss: 0.0183 - mse: 0.0183 - val_loss: 0.4903 - val_mse: 0.4903
# Epoch 284/500
# 8/8 - 2s - loss: 0.0187 - mse: 0.0187 - val_loss: 0.4902 - val_mse: 0.4902
# Epoch 285/500
# 8/8 - 2s - loss: 0.0178 - mse: 0.0178 - val_loss: 0.4774 - val_mse: 0.4774
# Epoch 286/500
# 8/8 - 2s - loss: 0.0182 - mse: 0.0182 - val_loss: 0.4853 - val_mse: 0.4853
# Epoch 287/500
# 8/8 - 2s - loss: 0.0199 - mse: 0.0199 - val_loss: 0.4903 - val_mse: 0.4903
# Epoch 288/500
# 8/8 - 2s - loss: 0.0155 - mse: 0.0155 - val_loss: 0.4803 - val_mse: 0.4803
# Epoch 289/500
# 8/8 - 2s - loss: 0.0190 - mse: 0.0190 - val_loss: 0.4804 - val_mse: 0.4804
# Epoch 290/500
# 8/8 - 2s - loss: 0.0239 - mse: 0.0239 - val_loss: 0.5217 - val_mse: 0.5217
# Epoch 291/500
# 8/8 - 2s - loss: 0.0278 - mse: 0.0278 - val_loss: 0.5015 - val_mse: 0.5015
# Epoch 292/500
# 8/8 - 2s - loss: 0.0248 - mse: 0.0248 - val_loss: 0.4852 - val_mse: 0.4852
# Epoch 293/500
# 8/8 - 2s - loss: 0.0176 - mse: 0.0176 - val_loss: 0.4893 - val_mse: 0.4893
# Epoch 294/500
# 8/8 - 2s - loss: 0.0198 - mse: 0.0198 - val_loss: 0.4849 - val_mse: 0.4849
# Epoch 295/500
# 8/8 - 2s - loss: 0.0179 - mse: 0.0179 - val_loss: 0.4807 - val_mse: 0.4807
# Epoch 296/500
# 8/8 - 2s - loss: 0.0188 - mse: 0.0188 - val_loss: 0.5000 - val_mse: 0.5000
# Epoch 297/500
# 8/8 - 2s - loss: 0.0212 - mse: 0.0212 - val_loss: 0.4794 - val_mse: 0.4794
# Epoch 298/500
# 8/8 - 2s - loss: 0.0200 - mse: 0.0200 - val_loss: 0.4942 - val_mse: 0.4942
# Epoch 299/500
# 8/8 - 2s - loss: 0.0194 - mse: 0.0194 - val_loss: 0.4775 - val_mse: 0.4775
# Epoch 300/500
# 8/8 - 2s - loss: 0.0188 - mse: 0.0188 - val_loss: 0.4806 - val_mse: 0.4806
# Epoch 301/500
# 8/8 - 2s - loss: 0.0184 - mse: 0.0184 - val_loss: 0.4810 - val_mse: 0.4810
# Epoch 302/500
# 8/8 - 2s - loss: 0.0165 - mse: 0.0165 - val_loss: 0.4881 - val_mse: 0.4881
# Epoch 303/500
# 8/8 - 2s - loss: 0.0187 - mse: 0.0187 - val_loss: 0.4841 - val_mse: 0.4841
# Epoch 304/500
# 8/8 - 2s - loss: 0.0188 - mse: 0.0188 - val_loss: 0.4778 - val_mse: 0.4778
# Epoch 305/500
# 8/8 - 2s - loss: 0.0167 - mse: 0.0167 - val_loss: 0.4867 - val_mse: 0.4867
# Epoch 306/500
# 8/8 - 2s - loss: 0.0173 - mse: 0.0173 - val_loss: 0.4880 - val_mse: 0.4880
# Epoch 307/500
# 8/8 - 2s - loss: 0.0206 - mse: 0.0206 - val_loss: 0.4826 - val_mse: 0.4826
# Epoch 308/500
# 8/8 - 2s - loss: 0.0205 - mse: 0.0205 - val_loss: 0.4840 - val_mse: 0.4840
# Epoch 309/500
# 8/8 - 2s - loss: 0.0194 - mse: 0.0194 - val_loss: 0.4930 - val_mse: 0.4930
# Epoch 310/500
# 8/8 - 2s - loss: 0.0176 - mse: 0.0176 - val_loss: 0.4919 - val_mse: 0.4919
# Epoch 311/500
# 8/8 - 2s - loss: 0.0170 - mse: 0.0170 - val_loss: 0.4907 - val_mse: 0.4907
# Epoch 312/500
# 8/8 - 2s - loss: 0.0193 - mse: 0.0193 - val_loss: 0.4808 - val_mse: 0.4808
# Epoch 313/500
# 8/8 - 2s - loss: 0.0180 - mse: 0.0180 - val_loss: 0.5041 - val_mse: 0.5041
# Epoch 314/500
# 8/8 - 2s - loss: 0.0203 - mse: 0.0203 - val_loss: 0.4891 - val_mse: 0.4891
# Epoch 315/500
# 8/8 - 2s - loss: 0.0181 - mse: 0.0181 - val_loss: 0.4886 - val_mse: 0.4886
# Epoch 316/500
# 8/8 - 2s - loss: 0.0193 - mse: 0.0193 - val_loss: 0.4864 - val_mse: 0.4864
# Epoch 317/500
# 8/8 - 2s - loss: 0.0172 - mse: 0.0172 - val_loss: 0.4840 - val_mse: 0.4840
# Epoch 318/500
# 8/8 - 2s - loss: 0.0158 - mse: 0.0158 - val_loss: 0.4803 - val_mse: 0.4803
# Epoch 319/500
# 8/8 - 2s - loss: 0.0166 - mse: 0.0166 - val_loss: 0.4944 - val_mse: 0.4944
# Epoch 320/500
# 8/8 - 2s - loss: 0.0198 - mse: 0.0198 - val_loss: 0.4983 - val_mse: 0.4983
# Epoch 321/500
# 8/8 - 2s - loss: 0.0207 - mse: 0.0207 - val_loss: 0.4743 - val_mse: 0.4743
# Epoch 322/500
# 8/8 - 2s - loss: 0.0174 - mse: 0.0174 - val_loss: 0.4801 - val_mse: 0.4801
# Epoch 323/500
# 8/8 - 2s - loss: 0.0176 - mse: 0.0176 - val_loss: 0.4865 - val_mse: 0.4865
# Epoch 324/500
# 8/8 - 2s - loss: 0.0155 - mse: 0.0155 - val_loss: 0.4930 - val_mse: 0.4930
# Epoch 325/500
# 8/8 - 2s - loss: 0.0175 - mse: 0.0175 - val_loss: 0.4822 - val_mse: 0.4822
# Epoch 326/500
# 8/8 - 2s - loss: 0.0179 - mse: 0.0179 - val_loss: 0.4932 - val_mse: 0.4932
# Epoch 327/500
# 8/8 - 2s - loss: 0.0204 - mse: 0.0204 - val_loss: 0.4818 - val_mse: 0.4818
# Epoch 328/500
# 8/8 - 2s - loss: 0.0198 - mse: 0.0198 - val_loss: 0.4754 - val_mse: 0.4754
# Epoch 329/500
# 8/8 - 2s - loss: 0.0188 - mse: 0.0188 - val_loss: 0.4766 - val_mse: 0.4766
# Epoch 330/500
# 8/8 - 2s - loss: 0.0171 - mse: 0.0171 - val_loss: 0.4905 - val_mse: 0.4905
# Epoch 331/500
# 8/8 - 2s - loss: 0.0180 - mse: 0.0180 - val_loss: 0.4812 - val_mse: 0.4812
# Epoch 332/500
# 8/8 - 2s - loss: 0.0157 - mse: 0.0157 - val_loss: 0.4848 - val_mse: 0.4848
# Epoch 333/500
# 8/8 - 2s - loss: 0.0151 - mse: 0.0151 - val_loss: 0.4842 - val_mse: 0.4842
# Epoch 334/500
# 8/8 - 2s - loss: 0.0159 - mse: 0.0159 - val_loss: 0.4846 - val_mse: 0.4846
# Epoch 335/500
# 8/8 - 2s - loss: 0.0162 - mse: 0.0162 - val_loss: 0.4867 - val_mse: 0.4867
# Epoch 336/500
# 8/8 - 2s - loss: 0.0149 - mse: 0.0149 - val_loss: 0.4869 - val_mse: 0.4869
# Epoch 337/500
# 8/8 - 2s - loss: 0.0169 - mse: 0.0169 - val_loss: 0.4860 - val_mse: 0.4860
# Epoch 338/500
# 8/8 - 2s - loss: 0.0181 - mse: 0.0181 - val_loss: 0.4943 - val_mse: 0.4943
# Epoch 339/500
# 8/8 - 2s - loss: 0.0154 - mse: 0.0154 - val_loss: 0.4873 - val_mse: 0.4873
# Epoch 340/500
# 8/8 - 2s - loss: 0.0164 - mse: 0.0164 - val_loss: 0.4744 - val_mse: 0.4744
# Epoch 341/500
# 8/8 - 2s - loss: 0.0170 - mse: 0.0170 - val_loss: 0.4871 - val_mse: 0.4871
# Epoch 342/500
# 8/8 - 2s - loss: 0.0194 - mse: 0.0194 - val_loss: 0.4837 - val_mse: 0.4837
# Epoch 343/500
# 8/8 - 2s - loss: 0.0166 - mse: 0.0166 - val_loss: 0.4720 - val_mse: 0.4720
# Epoch 344/500
# 8/8 - 2s - loss: 0.0143 - mse: 0.0143 - val_loss: 0.4850 - val_mse: 0.4850
# Epoch 345/500
# 8/8 - 2s - loss: 0.0147 - mse: 0.0147 - val_loss: 0.4959 - val_mse: 0.4959
# Epoch 346/500
# 8/8 - 2s - loss: 0.0152 - mse: 0.0152 - val_loss: 0.4901 - val_mse: 0.4901
# Epoch 347/500
# 8/8 - 2s - loss: 0.0154 - mse: 0.0154 - val_loss: 0.4795 - val_mse: 0.4795
# Epoch 348/500
# 8/8 - 2s - loss: 0.0153 - mse: 0.0153 - val_loss: 0.4792 - val_mse: 0.4792
# Epoch 349/500
# 8/8 - 2s - loss: 0.0157 - mse: 0.0157 - val_loss: 0.4843 - val_mse: 0.4843
# Epoch 350/500
# 8/8 - 2s - loss: 0.0162 - mse: 0.0162 - val_loss: 0.4938 - val_mse: 0.4938
# Epoch 351/500
# 8/8 - 2s - loss: 0.0205 - mse: 0.0205 - val_loss: 0.5013 - val_mse: 0.5013
# Epoch 352/500
# 8/8 - 2s - loss: 0.0165 - mse: 0.0165 - val_loss: 0.4862 - val_mse: 0.4862
# Epoch 353/500
# 8/8 - 2s - loss: 0.0140 - mse: 0.0140 - val_loss: 0.4857 - val_mse: 0.4857
# Epoch 354/500
# 8/8 - 2s - loss: 0.0165 - mse: 0.0165 - val_loss: 0.4802 - val_mse: 0.4802
# Epoch 355/500
# 8/8 - 2s - loss: 0.0154 - mse: 0.0154 - val_loss: 0.4875 - val_mse: 0.4875
# Epoch 356/500
# 8/8 - 2s - loss: 0.0152 - mse: 0.0152 - val_loss: 0.4763 - val_mse: 0.4763
# Epoch 357/500
# 8/8 - 2s - loss: 0.0192 - mse: 0.0192 - val_loss: 0.4835 - val_mse: 0.4835
# Epoch 358/500
# 8/8 - 2s - loss: 0.0171 - mse: 0.0171 - val_loss: 0.4869 - val_mse: 0.4869
# Epoch 359/500
# 8/8 - 2s - loss: 0.0166 - mse: 0.0166 - val_loss: 0.4932 - val_mse: 0.4932
# Epoch 360/500
# 8/8 - 2s - loss: 0.0161 - mse: 0.0161 - val_loss: 0.4917 - val_mse: 0.4917
# Epoch 361/500
# 8/8 - 2s - loss: 0.0157 - mse: 0.0157 - val_loss: 0.4889 - val_mse: 0.4889
# Epoch 362/500
# 8/8 - 2s - loss: 0.0176 - mse: 0.0176 - val_loss: 0.4903 - val_mse: 0.4903
# Epoch 363/500
# 8/8 - 2s - loss: 0.0178 - mse: 0.0178 - val_loss: 0.5030 - val_mse: 0.5030
# Epoch 364/500
# 8/8 - 2s - loss: 0.0187 - mse: 0.0187 - val_loss: 0.4892 - val_mse: 0.4892
# Epoch 365/500
# 8/8 - 2s - loss: 0.0289 - mse: 0.0289 - val_loss: 0.4862 - val_mse: 0.4862
# Epoch 366/500
# 8/8 - 2s - loss: 0.0291 - mse: 0.0291 - val_loss: 0.5067 - val_mse: 0.5067
# Epoch 367/500
# 8/8 - 2s - loss: 0.0238 - mse: 0.0238 - val_loss: 0.4841 - val_mse: 0.4841
# Epoch 368/500
# 8/8 - 2s - loss: 0.0179 - mse: 0.0179 - val_loss: 0.4866 - val_mse: 0.4866
# Epoch 369/500
# 8/8 - 2s - loss: 0.0158 - mse: 0.0158 - val_loss: 0.4902 - val_mse: 0.4902
# Epoch 370/500
# 8/8 - 2s - loss: 0.0176 - mse: 0.0176 - val_loss: 0.4996 - val_mse: 0.4996
# Epoch 371/500
# 8/8 - 2s - loss: 0.0180 - mse: 0.0180 - val_loss: 0.4974 - val_mse: 0.4974
# Epoch 372/500
# 8/8 - 2s - loss: 0.0187 - mse: 0.0187 - val_loss: 0.4985 - val_mse: 0.4985
# Epoch 373/500
# 8/8 - 2s - loss: 0.0170 - mse: 0.0170 - val_loss: 0.5022 - val_mse: 0.5022
# Epoch 374/500
# 8/8 - 2s - loss: 0.0154 - mse: 0.0154 - val_loss: 0.4861 - val_mse: 0.4861
# Epoch 375/500
# 8/8 - 2s - loss: 0.0154 - mse: 0.0154 - val_loss: 0.4883 - val_mse: 0.4883
# Epoch 376/500
# 8/8 - 2s - loss: 0.0152 - mse: 0.0152 - val_loss: 0.4947 - val_mse: 0.4947
# Epoch 377/500
# 8/8 - 2s - loss: 0.0158 - mse: 0.0158 - val_loss: 0.4930 - val_mse: 0.4930
# Epoch 378/500
# 8/8 - 2s - loss: 0.0158 - mse: 0.0158 - val_loss: 0.4853 - val_mse: 0.4853
# Epoch 379/500
# 8/8 - 2s - loss: 0.0152 - mse: 0.0152 - val_loss: 0.4917 - val_mse: 0.4917
# Epoch 380/500
# 8/8 - 2s - loss: 0.0145 - mse: 0.0145 - val_loss: 0.4975 - val_mse: 0.4975
# Epoch 381/500
# 8/8 - 2s - loss: 0.0148 - mse: 0.0148 - val_loss: 0.4817 - val_mse: 0.4817
# Epoch 382/500
# 8/8 - 2s - loss: 0.0137 - mse: 0.0137 - val_loss: 0.4892 - val_mse: 0.4892
# Epoch 383/500
# 8/8 - 2s - loss: 0.0134 - mse: 0.0134 - val_loss: 0.4827 - val_mse: 0.4827
# Epoch 384/500
# 8/8 - 2s - loss: 0.0149 - mse: 0.0149 - val_loss: 0.4824 - val_mse: 0.4824
# Epoch 385/500
# 8/8 - 2s - loss: 0.0145 - mse: 0.0145 - val_loss: 0.4831 - val_mse: 0.4831
# Epoch 386/500
# 8/8 - 2s - loss: 0.0148 - mse: 0.0148 - val_loss: 0.4920 - val_mse: 0.4920
# Epoch 387/500
# 8/8 - 2s - loss: 0.0145 - mse: 0.0145 - val_loss: 0.4877 - val_mse: 0.4877
# Epoch 388/500
# 8/8 - 2s - loss: 0.0151 - mse: 0.0151 - val_loss: 0.4848 - val_mse: 0.4848
# Epoch 389/500
# 8/8 - 2s - loss: 0.0141 - mse: 0.0141 - val_loss: 0.4860 - val_mse: 0.4860
# Epoch 390/500
# 8/8 - 2s - loss: 0.0139 - mse: 0.0139 - val_loss: 0.4842 - val_mse: 0.4842
# Epoch 391/500
# 8/8 - 2s - loss: 0.0143 - mse: 0.0143 - val_loss: 0.4935 - val_mse: 0.4935
# Epoch 392/500
# 8/8 - 2s - loss: 0.0178 - mse: 0.0178 - val_loss: 0.4989 - val_mse: 0.4989
# Epoch 393/500
# 8/8 - 2s - loss: 0.0183 - mse: 0.0183 - val_loss: 0.4805 - val_mse: 0.4805
# Epoch 394/500
# 8/8 - 2s - loss: 0.0151 - mse: 0.0151 - val_loss: 0.4755 - val_mse: 0.4755
# Epoch 395/500
# 8/8 - 2s - loss: 0.0128 - mse: 0.0128 - val_loss: 0.4814 - val_mse: 0.4814
# Epoch 396/500
# 8/8 - 2s - loss: 0.0133 - mse: 0.0133 - val_loss: 0.4916 - val_mse: 0.4916
# Epoch 397/500
# 8/8 - 2s - loss: 0.0153 - mse: 0.0153 - val_loss: 0.4959 - val_mse: 0.4959
# Epoch 398/500
# 8/8 - 2s - loss: 0.0180 - mse: 0.0180 - val_loss: 0.4878 - val_mse: 0.4878
# Epoch 399/500
# 8/8 - 2s - loss: 0.0144 - mse: 0.0144 - val_loss: 0.4973 - val_mse: 0.4973
# Epoch 400/500
# 8/8 - 2s - loss: 0.0149 - mse: 0.0149 - val_loss: 0.4909 - val_mse: 0.4909
# Epoch 401/500
# 8/8 - 2s - loss: 0.0141 - mse: 0.0141 - val_loss: 0.4906 - val_mse: 0.4906
# Epoch 402/500
# 8/8 - 2s - loss: 0.0127 - mse: 0.0127 - val_loss: 0.4806 - val_mse: 0.4806
# Epoch 403/500
# 8/8 - 2s - loss: 0.0137 - mse: 0.0137 - val_loss: 0.4820 - val_mse: 0.4820
# Epoch 404/500
# 8/8 - 2s - loss: 0.0168 - mse: 0.0168 - val_loss: 0.4862 - val_mse: 0.4862
# Epoch 405/500
# 8/8 - 2s - loss: 0.0147 - mse: 0.0147 - val_loss: 0.5003 - val_mse: 0.5003
# Epoch 406/500
# 8/8 - 2s - loss: 0.0137 - mse: 0.0137 - val_loss: 0.4903 - val_mse: 0.4903
# Epoch 407/500
# 8/8 - 2s - loss: 0.0145 - mse: 0.0145 - val_loss: 0.4964 - val_mse: 0.4964
# Epoch 408/500
# 8/8 - 2s - loss: 0.0153 - mse: 0.0153 - val_loss: 0.4904 - val_mse: 0.4904
# Epoch 409/500
# 8/8 - 2s - loss: 0.0152 - mse: 0.0152 - val_loss: 0.4961 - val_mse: 0.4961
# Epoch 410/500
# 8/8 - 2s - loss: 0.0166 - mse: 0.0166 - val_loss: 0.4814 - val_mse: 0.4814
# Epoch 411/500
# 8/8 - 2s - loss: 0.0170 - mse: 0.0170 - val_loss: 0.4926 - val_mse: 0.4926
# Epoch 412/500
# 8/8 - 2s - loss: 0.0156 - mse: 0.0156 - val_loss: 0.4928 - val_mse: 0.4928
# Epoch 413/500
# 8/8 - 2s - loss: 0.0184 - mse: 0.0184 - val_loss: 0.5027 - val_mse: 0.5027
# Epoch 414/500
# 8/8 - 2s - loss: 0.0169 - mse: 0.0169 - val_loss: 0.4864 - val_mse: 0.4864
# Epoch 415/500
# 8/8 - 2s - loss: 0.0141 - mse: 0.0141 - val_loss: 0.4896 - val_mse: 0.4896
# Epoch 416/500
# 8/8 - 2s - loss: 0.0128 - mse: 0.0128 - val_loss: 0.4936 - val_mse: 0.4936
# Epoch 417/500
# 8/8 - 2s - loss: 0.0121 - mse: 0.0121 - val_loss: 0.4848 - val_mse: 0.4848
# Epoch 418/500
# 8/8 - 2s - loss: 0.0137 - mse: 0.0137 - val_loss: 0.4833 - val_mse: 0.4833
# Epoch 419/500
# 8/8 - 2s - loss: 0.0122 - mse: 0.0122 - val_loss: 0.4926 - val_mse: 0.4926
# Epoch 420/500
# 8/8 - 2s - loss: 0.0131 - mse: 0.0131 - val_loss: 0.4892 - val_mse: 0.4892
# Epoch 421/500
# 8/8 - 2s - loss: 0.0141 - mse: 0.0141 - val_loss: 0.4907 - val_mse: 0.4907
# Epoch 422/500
# 8/8 - 2s - loss: 0.0117 - mse: 0.0117 - val_loss: 0.4939 - val_mse: 0.4939
# Epoch 423/500
# 8/8 - 2s - loss: 0.0120 - mse: 0.0120 - val_loss: 0.4855 - val_mse: 0.4855
# Epoch 424/500
# 8/8 - 2s - loss: 0.0136 - mse: 0.0136 - val_loss: 0.4873 - val_mse: 0.4873
# Epoch 425/500
# 8/8 - 2s - loss: 0.0153 - mse: 0.0153 - val_loss: 0.4944 - val_mse: 0.4944
# Epoch 426/500
# 8/8 - 2s - loss: 0.0118 - mse: 0.0118 - val_loss: 0.4981 - val_mse: 0.4981
# Epoch 427/500
# 8/8 - 2s - loss: 0.0137 - mse: 0.0137 - val_loss: 0.4844 - val_mse: 0.4844
# Epoch 428/500
# 8/8 - 2s - loss: 0.0128 - mse: 0.0128 - val_loss: 0.4911 - val_mse: 0.4911
# Epoch 429/500
# 8/8 - 2s - loss: 0.0128 - mse: 0.0128 - val_loss: 0.4991 - val_mse: 0.4991
# Epoch 430/500
# 8/8 - 2s - loss: 0.0136 - mse: 0.0136 - val_loss: 0.4982 - val_mse: 0.4982
# Epoch 431/500
# 8/8 - 2s - loss: 0.0154 - mse: 0.0154 - val_loss: 0.4953 - val_mse: 0.4953
# Epoch 432/500
# 8/8 - 2s - loss: 0.0122 - mse: 0.0122 - val_loss: 0.4871 - val_mse: 0.4871
# Epoch 433/500
# 8/8 - 2s - loss: 0.0163 - mse: 0.0163 - val_loss: 0.5000 - val_mse: 0.5000
# Epoch 434/500
# 8/8 - 2s - loss: 0.0162 - mse: 0.0162 - val_loss: 0.4854 - val_mse: 0.4854
# Epoch 435/500
# 8/8 - 2s - loss: 0.0150 - mse: 0.0150 - val_loss: 0.4900 - val_mse: 0.4900
# Epoch 436/500
# 8/8 - 2s - loss: 0.0179 - mse: 0.0179 - val_loss: 0.5084 - val_mse: 0.5084
# Epoch 437/500
# 8/8 - 2s - loss: 0.0221 - mse: 0.0221 - val_loss: 0.5078 - val_mse: 0.5078
# Epoch 438/500
# 8/8 - 2s - loss: 0.0180 - mse: 0.0180 - val_loss: 0.4969 - val_mse: 0.4969
# Epoch 439/500
# 8/8 - 2s - loss: 0.0158 - mse: 0.0158 - val_loss: 0.4802 - val_mse: 0.4802
# Epoch 440/500
# 8/8 - 2s - loss: 0.0149 - mse: 0.0149 - val_loss: 0.4907 - val_mse: 0.4907
# Epoch 441/500
# 8/8 - 2s - loss: 0.0135 - mse: 0.0135 - val_loss: 0.4845 - val_mse: 0.4845
# Epoch 442/500
# 8/8 - 2s - loss: 0.0151 - mse: 0.0151 - val_loss: 0.4868 - val_mse: 0.4868
# Epoch 443/500
# 8/8 - 2s - loss: 0.0145 - mse: 0.0145 - val_loss: 0.5097 - val_mse: 0.5097
# Epoch 444/500
# 8/8 - 2s - loss: 0.0164 - mse: 0.0164 - val_loss: 0.4991 - val_mse: 0.4991
# Epoch 445/500
# 8/8 - 2s - loss: 0.0165 - mse: 0.0165 - val_loss: 0.4780 - val_mse: 0.4780
# Epoch 446/500
# 8/8 - 2s - loss: 0.0127 - mse: 0.0127 - val_loss: 0.4886 - val_mse: 0.4886
# Epoch 447/500
# 8/8 - 2s - loss: 0.0150 - mse: 0.0150 - val_loss: 0.4890 - val_mse: 0.4890
# Epoch 448/500
# 8/8 - 2s - loss: 0.0150 - mse: 0.0150 - val_loss: 0.4978 - val_mse: 0.4978
# Epoch 449/500
# 8/8 - 2s - loss: 0.0146 - mse: 0.0146 - val_loss: 0.4850 - val_mse: 0.4850
# Epoch 450/500
# 8/8 - 2s - loss: 0.0151 - mse: 0.0151 - val_loss: 0.4931 - val_mse: 0.4931
# Epoch 451/500
# 8/8 - 2s - loss: 0.0153 - mse: 0.0153 - val_loss: 0.4857 - val_mse: 0.4857
# Epoch 452/500
# 8/8 - 2s - loss: 0.0143 - mse: 0.0143 - val_loss: 0.4856 - val_mse: 0.4856
# Epoch 453/500
# 8/8 - 2s - loss: 0.0139 - mse: 0.0139 - val_loss: 0.4961 - val_mse: 0.4961
# Epoch 454/500
# 8/8 - 2s - loss: 0.0132 - mse: 0.0132 - val_loss: 0.4827 - val_mse: 0.4827
# Epoch 455/500
# 8/8 - 2s - loss: 0.0155 - mse: 0.0155 - val_loss: 0.4890 - val_mse: 0.4890
# Epoch 456/500
# 8/8 - 2s - loss: 0.0161 - mse: 0.0161 - val_loss: 0.4832 - val_mse: 0.4832
# Epoch 457/500
# 8/8 - 2s - loss: 0.0150 - mse: 0.0150 - val_loss: 0.5020 - val_mse: 0.5020
# Epoch 458/500
# 8/8 - 2s - loss: 0.0153 - mse: 0.0153 - val_loss: 0.5029 - val_mse: 0.5029
# Epoch 459/500
# 8/8 - 2s - loss: 0.0121 - mse: 0.0121 - val_loss: 0.4922 - val_mse: 0.4922
# Epoch 460/500
# 8/8 - 2s - loss: 0.0115 - mse: 0.0115 - val_loss: 0.4818 - val_mse: 0.4818
# Epoch 461/500
# 8/8 - 2s - loss: 0.0140 - mse: 0.0140 - val_loss: 0.4968 - val_mse: 0.4968
# Epoch 462/500
# 8/8 - 2s - loss: 0.0137 - mse: 0.0137 - val_loss: 0.4932 - val_mse: 0.4932
# Epoch 463/500
# 8/8 - 2s - loss: 0.0134 - mse: 0.0134 - val_loss: 0.4945 - val_mse: 0.4945
# Epoch 464/500
# 8/8 - 2s - loss: 0.0111 - mse: 0.0111 - val_loss: 0.4842 - val_mse: 0.4842
# Epoch 465/500
# 8/8 - 2s - loss: 0.0117 - mse: 0.0117 - val_loss: 0.4871 - val_mse: 0.4871
# Epoch 466/500
# 8/8 - 2s - loss: 0.0114 - mse: 0.0114 - val_loss: 0.4856 - val_mse: 0.4856
# Epoch 467/500
# 8/8 - 2s - loss: 0.0117 - mse: 0.0117 - val_loss: 0.4985 - val_mse: 0.4985
# Epoch 468/500
# 8/8 - 2s - loss: 0.0124 - mse: 0.0124 - val_loss: 0.5005 - val_mse: 0.5005
# Epoch 469/500
# 8/8 - 2s - loss: 0.0131 - mse: 0.0131 - val_loss: 0.4817 - val_mse: 0.4817
# Epoch 470/500
# 8/8 - 2s - loss: 0.0139 - mse: 0.0139 - val_loss: 0.4825 - val_mse: 0.4825
# Epoch 471/500
# 8/8 - 2s - loss: 0.0121 - mse: 0.0121 - val_loss: 0.4906 - val_mse: 0.4906
# Epoch 472/500
# 8/8 - 2s - loss: 0.0125 - mse: 0.0125 - val_loss: 0.4908 - val_mse: 0.4908
# Epoch 473/500
# 8/8 - 2s - loss: 0.0131 - mse: 0.0131 - val_loss: 0.4873 - val_mse: 0.4873
# Epoch 474/500
# 8/8 - 2s - loss: 0.0130 - mse: 0.0130 - val_loss: 0.4930 - val_mse: 0.4930
# Epoch 475/500
# 8/8 - 2s - loss: 0.0119 - mse: 0.0119 - val_loss: 0.4886 - val_mse: 0.4886
# Epoch 476/500
# 8/8 - 2s - loss: 0.0114 - mse: 0.0114 - val_loss: 0.4889 - val_mse: 0.4889
# Epoch 477/500
# 8/8 - 2s - loss: 0.0120 - mse: 0.0120 - val_loss: 0.4797 - val_mse: 0.4797
# Epoch 478/500
# 8/8 - 2s - loss: 0.0126 - mse: 0.0126 - val_loss: 0.4862 - val_mse: 0.4862
# Epoch 479/500
# 8/8 - 2s - loss: 0.0127 - mse: 0.0127 - val_loss: 0.4888 - val_mse: 0.4888
# Epoch 480/500
# 8/8 - 2s - loss: 0.0133 - mse: 0.0133 - val_loss: 0.4922 - val_mse: 0.4922
# Epoch 481/500
# 8/8 - 2s - loss: 0.0137 - mse: 0.0137 - val_loss: 0.4925 - val_mse: 0.4925
# Epoch 482/500
# 8/8 - 2s - loss: 0.0122 - mse: 0.0122 - val_loss: 0.4839 - val_mse: 0.4839
# Epoch 483/500
# 8/8 - 2s - loss: 0.0107 - mse: 0.0107 - val_loss: 0.4873 - val_mse: 0.4873
# Epoch 484/500
# 8/8 - 2s - loss: 0.0119 - mse: 0.0119 - val_loss: 0.4875 - val_mse: 0.4875
# Epoch 485/500
# 8/8 - 2s - loss: 0.0110 - mse: 0.0110 - val_loss: 0.4900 - val_mse: 0.4900
# Epoch 486/500
# 8/8 - 2s - loss: 0.0130 - mse: 0.0130 - val_loss: 0.4869 - val_mse: 0.4869
# Epoch 487/500
# 8/8 - 2s - loss: 0.0120 - mse: 0.0120 - val_loss: 0.4859 - val_mse: 0.4859
# Epoch 488/500
# 8/8 - 2s - loss: 0.0126 - mse: 0.0126 - val_loss: 0.5070 - val_mse: 0.5070
# Epoch 489/500
# 8/8 - 2s - loss: 0.0119 - mse: 0.0119 - val_loss: 0.4962 - val_mse: 0.4962
# Epoch 490/500
# 8/8 - 2s - loss: 0.0113 - mse: 0.0113 - val_loss: 0.4928 - val_mse: 0.4928
# Epoch 491/500
# 8/8 - 2s - loss: 0.0112 - mse: 0.0112 - val_loss: 0.4900 - val_mse: 0.4900
# Epoch 492/500
# 8/8 - 2s - loss: 0.0092 - mse: 0.0092 - val_loss: 0.4965 - val_mse: 0.4965
# Epoch 493/500
# 8/8 - 2s - loss: 0.0122 - mse: 0.0122 - val_loss: 0.4933 - val_mse: 0.4933
# Epoch 494/500
# 8/8 - 2s - loss: 0.0109 - mse: 0.0109 - val_loss: 0.5086 - val_mse: 0.5086
# Epoch 495/500
# 8/8 - 2s - loss: 0.0115 - mse: 0.0115 - val_loss: 0.4972 - val_mse: 0.4972
# Epoch 496/500
# 8/8 - 2s - loss: 0.0117 - mse: 0.0117 - val_loss: 0.4978 - val_mse: 0.4978
# Epoch 497/500
# 8/8 - 2s - loss: 0.0126 - mse: 0.0126 - val_loss: 0.4976 - val_mse: 0.4976
# Epoch 498/500
# 8/8 - 2s - loss: 0.0120 - mse: 0.0120 - val_loss: 0.4921 - val_mse: 0.4921
# Epoch 499/500
# 8/8 - 2s - loss: 0.0108 - mse: 0.0108 - val_loss: 0.4875 - val_mse: 0.4875
# Epoch 500/500
# 8/8 - 2s - loss: 0.0100 - mse: 0.0100 - val_loss: 0.4843 - val_mse: 0.4843
